# %%
from unicodedata import normalize
import pandas as pd

# %%
df = pd.read_csv("dict.csv")

# %%
df.sample(10)
# Out:
#                 noun        support  len  variation  \
# 10773   chanfaneiros    chanfaneiro   12          4
# 7109    antropófagas    antropófago   12          4
# 4147        tumbeiro       tumbeiro    8          4
# 2743          ganesa          ganês    6          4
# 10771   chanfaneiras    chanfaneiro   12          4
# 11232      clamadora       clamador    9          4
# 21311  intermediária  intermediário   13          4
# 15409    molestadora     molestador   11          4
# 12950      cavaleiro      cavaleiro    9          4
# 10381   checoslovaca   checoslovaco   12          4
#
#                                                  meaning
# 10773  [{'class': '', 'meanings': ['Chanfaneiros é o ...
# 7109    {'error': 'Request failed with status code 404'}
# 4147   [{'class': 'adjetivo', 'meanings': ['Que se re...
# 2743   [{'class': '', 'meanings': ['Ganesa é o femini...
# 10771   {'error': 'Request failed with status code 404'}
# ...

# %%
df.to_csv('data.csv', index = False)
