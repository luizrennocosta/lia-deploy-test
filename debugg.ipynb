# %%
from unicodedata import normalize
import pandas as pd

# %%
def pt_normalize(word):
        return normalize("NFKD", word).encode("ASCII", "ignore").decode("ASCII")

# %%
df = pd.read_csv("all_nouns.csv")

# %%
df.head(10)
# Out:
#          noun     support  len  variation
# 0      alares      alares    6          1
# 1  hesperides  hesperides   10          1
# 2    escassez    escassez    8          1
# 3      tempao      tempao    6          1
# 4      xalmas      xalmas    6          1
# 5     pleuris     pleuris    7          1
# 6       fiote       fiote    5          1
# 7    gentinha    gentinha    8          1
# 8     balugas     balugas    7          1
# 9        idos        idos    4          1

# %%
df['noun'] = df['noun'].apply(pt_normalize)
df['support'] = df['support'].apply(pt_normalize)

# %%
dict = {'noun': ['desenvolvedor', 'desenvolvedora', 'desenvolvedores', 'desenvolvedoras'], 
        'support': ['desenvolvedor', 'desenvolvedor', 'desenvolvedor', 'desenvolvedor'], 
        'len': [13, 14, 15, 15],
        'variation': [4, 4, 4, 4],
       }

df = df.append(dict, ignore_index = True)

# %%
df
# Out:
#                                                      noun  \
# 0                                                  alares
# 1                                              hesperides
# 2                                                escassez
# 3                                                  tempao
# 4                                                  xalmas
# ...                                                   ...
# 130419                                             nuinho
# 130420                                            nuinhas
# 130421                                            ladrona
# 130422                                           ladritas
# 130423  [desenvolvedor, desenvolvedora, desenvolvedore...
#
#                                                   support               len  \
# 0                                                  alares                 6
# 1                                              hesperides                10
# 2                                                escassez                 8
# 3                                                  tempao                 6
# 4                                                  xalmas                 6
# ...                                                   ...               ...
# 130419                                                 nu                 6
# 130420                                                 nu                 7
# 130421                                             ladrao                 7
# 130422                                             ladrao                 8
# 130423  [desenvolvedor, desenvolvedor, desenvolvedor, ...  [13, 14, 15, 15]
#
#            variation
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ...              ...
# 130419            24
# 130420            24
# 130421            24
# 130422            24
# 130423  [4, 4, 4, 4]
#
# [130424 rows x 4 columns]

# %%
df[df.noun.str.contains('desenvolv')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-72c1272d0496> in <module>
# ----> 1 df[df.noun.str.contains('desenvolv')]
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2894
#    2895         # Do we have a (boolean) 1d indexer?
# -> 2896         if com.is_bool_indexer(key):
#    2897             return self._getitem_bool_array(key)
#    2898
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/common.py in is_bool_indexer(key)
#     132                 na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     133                 if isna(key).any():
# --> 134                     raise ValueError(na_msg)
#     135                 return False
#     136             return True
#
# ValueError: Cannot mask with non-boolean array containing NA / NaN values

# %%
# df.to_csv('all_nouns.csv', index = False)
